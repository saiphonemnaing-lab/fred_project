# %%
# giving the exact path to the Python executable in the current environment, so that the package is installed in the correct environment.
import sys

# !{sys.executable} -m pip install fredapi    # installing the fredapi package using pip
from fredapi import Fred

# %%
# inputting the API key to access the FRED data
fred = Fred(api_key='44ffecad7176178b4de2a1b476b4f617')

# calling the get_series method to retrieve the data for the specified series ID 'CORESTICKM159SFRBATL' and storing it in the variable 'cpi'
cpi = fred.get_series('CORESTICKM159SFRBATL')
print(cpi)
# Out:
# 1967-12-01         NaN
# 1968-01-01    3.651861
# 1968-02-01    3.673819
# 1968-03-01    4.142164
# 1968-04-01    4.155828
#                 ...
# 2026-01-01    2.979751
# 2026-02-01    2.903909
# 2026-03-01    2.929321
# 2026-04-01    3.038932
# 2026-05-01    3.091257
# Length: 702, dtype: float64

# %%
# calling the get_series method to retrieve the data for the specified series ID 'GDP' and storing it in the variable 'gdp'
gdp = fred.get_series('GDP')
print(gdp)
# Out:
# 1946-01-01          NaN
# 1946-04-01          NaN
# 1946-07-01          NaN
# 1946-10-01          NaN
# 1947-01-01      243.164
#                 ...
# 2025-01-01    30042.113
# 2025-04-01    30485.729
# 2025-07-01    31098.027
# 2025-10-01    31422.526
# 2026-01-01    31819.464
# Length: 321, dtype: float64

# %%
# calling the get_series method to retrieve the data for the specified series ID 'GDPC1' and storing it in the variable 'rgdp'
rgdp = fred.get_series('GDPC1')
print(rgdp)
# Out:
# 1947-01-01     2182.681
# 1947-04-01     2176.892
# 1947-07-01     2172.432
# 1947-10-01     2206.452
# 1948-01-01     2239.682
#                 ...
# 2025-01-01    23548.210
# 2025-04-01    23770.976
# 2025-07-01    24026.834
# 2025-10-01    24055.749
# 2026-01-01    24152.656
# Length: 317, dtype: float64

# %%
# calling the get_series method to retrieve the data for the specified series ID 'UNRATE' and storing it in the variable 'unrate'
unrate = fred.get_series('UNRATE')
print(unrate)
# Out:
# 1948-01-01    3.4
# 1948-02-01    3.8
# 1948-03-01    4.0
# 1948-04-01    3.9
# 1948-05-01    3.5
#              ...
# 2026-01-01    4.3
# 2026-02-01    4.4
# 2026-03-01    4.3
# 2026-04-01    4.3
# 2026-05-01    4.3
# Length: 941, dtype: float64

# %%
# calling the get_series method to retrieve the data for the specified series ID 'IR3TCD01USM156N' and storing it in the variable 'cd'
cd = fred.get_series('IR3TCD01USM156N')
print(cd)
# Out:
# 1964-06-01    3.86
# 1964-07-01    3.87
# 1964-08-01    3.85
# 1964-09-01    3.87
# 1964-10-01    3.94
#               ...
# 2023-08-01    5.44
# 2023-09-01    5.49
# 2023-10-01    5.46
# 2023-11-01    5.41
# 2023-12-01    5.32
# Length: 715, dtype: float64

# %%
# calling the get_series method to retrieve the data for the specified series ID 'FEDFUNDS' and storing it in the variable 'ffer'
ffer = fred.get_series('FEDFUNDS')
print(ffer)
# Out:
# 1954-07-01    0.80
# 1954-08-01    1.22
# 1954-09-01    1.07
# 1954-10-01    0.85
# 1954-11-01    0.83
#               ...
# 2026-01-01    3.64
# 2026-02-01    3.64
# 2026-03-01    3.64
# 2026-04-01    3.64
# 2026-05-01    3.63
# Length: 863, dtype: float64

# %%
# calling the get_series method to retrieve the data for the specified series ID 'T10Y2Y' and storing it in the variable 't10y2y'
t10y2y = fred.get_series('T10Y2Y')
print(t10y2y)
# Out:
# 1976-06-01    0.68
# 1976-06-02    0.71
# 1976-06-03    0.70
# 1976-06-04    0.77
# 1976-06-07    0.79
#               ...
# 2026-06-18    0.27
# 2026-06-19     NaN
# 2026-06-22    0.27
# 2026-06-23    0.34
# 2026-06-24    0.30
# Length: 13062, dtype: float64
