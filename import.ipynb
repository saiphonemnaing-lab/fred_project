# %%
import sys
# !{sys.executable} -m pip install fredapi
from fredapi import Fred
# Out:
# ...
#   Using cached fredapi-0.5.2-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached fredapi-0.5.2-py3-none-any.whl (11 kB)
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip3 install --upgrade pip

# %%
fred = Fred(api_key='44ffecad7176178b4de2a1b476b4f617')
cpi = fred.get_series('CORESTICKM159SFRBATL')
print(cpi)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 """Send a complete request to the server."""
# -> 1336 self._send_request(method, url, body, headers, encode_chunked)
#
# ...

# %%
import pandas as pd

# %%
import os

path = '/Users/stevenaing/Documents/Fred project/fred_project/CPI/monthly.csv'
if not os.path.exists(path):
	alt = os.path.expanduser('~/Documents/Fred project/fred_project/CPI/monthly.csv')
	if os.path.exists(alt):
		path = alt
	else:
		os.makedirs(os.path.dirname(path), exist_ok=True)
		series = fred.get_series('CORESTICKM159SFRBATL')
		series.to_csv(path, header=True)
cpi = pd.read_csv(path, index_col=0, parse_dates=True)
print(cpi.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 cpi = pd.read_csv('Users/stevenaing/Documents/Fred project/fred_project/CPI/monthly.csv')
#
# ...
